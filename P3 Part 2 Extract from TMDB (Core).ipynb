# %% [markdown]
# ## Your Stakeholder Wants More Data!

# %% [markdown]
# After investigating the preview of your data from Part 1, your stakeholder realized that there is no financial information included in the IMDB data (e.g. budget or revenue).
#
#    - This will be a major roadblock when attempting to analyze which movies are successful and must be addressed before you will be able to determine which movies are successful.
#
#    - Your stakeholder identified The Movie Database (TMDB) as a great source of financial data (https://www.themoviedb.org/). Thankfully, TMDB offers a free API for programmatic access to their data!
#
#    - Your stakeholder wants you to extract the budget, revenue, and MPAA Rating (G/PG/PG-13/R), which is also called "Certification".
#
#    - Note: this process can take a long time and may need to run overnight.

# %% [markdown]
# ## Specification - Financial Data

# %% [markdown]
# Your stakeholder would like you to extract and save the results for movies that meet all of the criteria established in part 1 of the project (You should already have a filtered dataframe saved from part one as a csv.gz file)
#
#    - As a proof-of-concept, they requested you perform a test extraction of movies that started in 2000 or 2001
#
#    - Each year should be saved as a separate .csv.gz file
#
# Hint: Use the two custom functions from the lessons (Intro to TMDB API, and Efficient TMDB API Calls). Be sure to define these functions prior to calling them in your code!
#
#    - One function will add the certification (MPGG Rating) to movie.info
#    - The other function will help you append/extend a JSON file with Python
#
#
# ### Confirm Your API Function works.
#
# In order to ensure your function for extracting movie data from TMDB is working, test your function on these 2 movie ids: tt0848228 ("The Avengers") and tt0332280 ("The Notebook"). Make sure that your function runs without error and that it returns the correct movie's data for both test ids.
#
# Hint: Ideally you can organize the code segments from the previous lesson to create an outer and inner loop, but if you get stuck, you can complete 1 year at a time.
#
#  - Once you have retrieved and saved the final results to 2 separate .csv.gz files, move on to a new Exploratory Data Analysis notebook to explore the following questions.

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# - Load in your csv.gz's of results for each year extracted.
#     1. Concatenate the data into 1 dataframe for the remainder of the analysis.
# - Once you have your data from the API, they would like you to perform some light EDA to show:
#     1. How many movies had at least some valid financial information (values > 0 for budget OR revenue)?
#      - Please exclude any movies with 0's for budget AND revenue from the remaining visualizations.
#     2. How many movies are there in each of the certification categories (G/PG/PG-13/R)?
#     3. What is the average revenue per certification category?
#     4. What is the average budget per certification category?

# %% [markdown]
# ## Deliverables

# %% [markdown]
# After you have joined the tmdb results into 1 dataframe in the EDA Notebook,
#
# - Save a final merged .csv.gz of all of the tmdb api data
# - The file name should be "tmdb_results_combined.csv.gz"
# - Make sure this is pushed to your github repository along with all of your code
#     - One code file for API calls
#     - One code file for EDA
# - Submit the link

# %% [markdown]
# ---

# %% [markdown]
# ## Using the TMDB API

# %%
# !pip install tmdbsimple
# Out:
# Requirement already satisfied: tmdbsimple in c:\users\valma\anaconda3\envs\dojo-env\lib\site-packages (2.9.1)
# Requirement already satisfied: requests in c:\users\valma\anaconda3\envs\dojo-env\lib\site-packages (from tmdbsimple) (2.28.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\valma\anaconda3\envs\dojo-env\lib\site-packages (from requests->tmdbsimple) (1.26.13)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\valma\anaconda3\envs\dojo-env\lib\site-packages (from requests->tmdbsimple) (2022.9.24)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\valma\anaconda3\envs\dojo-env\lib\site-packages (from requests->tmdbsimple) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\valma\anaconda3\envs\dojo-env\lib\site-packages (from requests->tmdbsimple) (3.4)

# %%
import json
with open('/Users/valma/.secret/tmdb_api.json', 'r') as f:
    login = json.load(f)

login.keys()
# Out:
# dict_keys(['client-id', 'api-key'])

# %%
import tmdbsimple as tmdb
tmdb.API_KEY =  login['api-key']

# %%
movie = tmdb.Movies(603)
movie

# %%
info = movie.info()
info
# Out:
# {'adult': False,
#  'backdrop_path': '/oMsxZEvz9a708d49b6UdZK1KAo5.jpg',
#  'belongs_to_collection': {'id': 2344,
#   'name': 'The Matrix Collection',
#   'poster_path': '/bV9qTVHTVf0gkW0j7p7M0ILD4pG.jpg',
#   'backdrop_path': '/bRm2DEgUiYciDw3myHuYFInD7la.jpg'},
#  'budget': 63000000,
#  'genres': [{'id': 28, 'name': 'Action'},
#   {'id': 878, 'name': 'Science Fiction'}],
#  'homepage': 'http://www.warnerbros.com/matrix',
#  'id': 603,
#  'imdb_id': 'tt0133093',
#  'original_language': 'en',
#  'original_title': 'The Matrix',
#  'overview': 'Set in the 22nd century, The Matrix tells the story of a computer hacker who joins a group of underground insurgents fighting the vast and powerful computers who now rule the earth.',
#  'popularity': 97.006,
#  'poster_path': '/f89U3ADr1oiB1s9GkdPOEpXUk5H.jpg',
#  'production_companies': [{'id': 79,
#    'logo_path': '/tpFpsqbleCzEE2p5EgvUq6ozfCA.png',
#    'name': 'Village Roadshow Pictures',
#    'origin_country': 'US'},
#   {'id': 372,
#    'logo_path': None,
#    'name': 'Groucho II Film Partnership',
#    'origin_country': ''},
#   {'id': 1885,
#    'logo_path': '/xlvoOZr4s1PygosrwZyolIFe5xs.png',
#    'name': 'Silver Pictures',
#    'origin_country': 'US'},
#   {'id': 174,
#    'logo_path': '/IuAlhI9eVC9Z8UQWOIDdWRKSEJ.png',
#    'name': 'Warner Bros. Pictures',
#    'origin_country': 'US'}],
#  'production_countries': [{'iso_3166_1': 'US',
#    'name': 'United States of America'}],
#  'release_date': '1999-03-30',
#  'revenue': 463517383,
#  'runtime': 136,
#  'spoken_languages': [{'english_name': 'English',
#    'iso_639_1': 'en',
#    'name': 'English'}],
#  'status': 'Released',
#  'tagline': 'Welcome to the Real World.',
#  'title': 'The Matrix',
#  'video': False,
#  'vote_average': 8.204,
#  'vote_count': 23435}

# %%
info['budget']
# Out:
# 63000000

# %%
info['revenue']
# Out:
# 463517383

# %%
info['imdb_id']
# Out:
# 'tt0133093'

# %%
movie = tmdb.Movies('tt1361336')
info = movie.info()
info['budget']
# Out:
# 50000000

# %%
response = movie.releases()

# %%
response
# Out:
# {'id': 587807,
#  'countries': [{'certification': '',
#    'descriptors': [],
#    'iso_3166_1': 'CO',
#    'primary': False,
#    'release_date': '2021-02-12'},
#   {'certification': 'PG',
#    'descriptors': [],
#    'iso_3166_1': 'US',
#    'primary': False,
#    'release_date': '2021-02-26'},
#   {'certification': 'ALL',
#    'descriptors': [],
#    'iso_3166_1': 'KR',
#    'primary': False,
#    'release_date': '2021-02-24'},
#   {'certification': '',
#    'descriptors': [],
#    'iso_3166_1': 'ID',
#    'primary': False,
#    'release_date': '2021-03-10'},
#   {'certification': '6',
#    'descriptors': [],
#    'iso_3166_1': 'NL',
#    'primary': False,
#    'release_date': '2021-06-09'},
#   {'certification': 'G',
#    'descriptors': [],
#    'iso_3166_1': 'IE',
#    'primary': False,
#    'release_date': '2021-05-07'},
#   {'certification': 'M/6',
#    'descriptors': [],
#    'iso_3166_1': 'PT',
#    'primary': False,
#    'release_date': '2021-03-04'},
#   {'certification': '6+',
#    'descriptors': [],
#    'iso_3166_1': 'RU',
#    'primary': False,
#    'release_date': '2021-02-25'},
#   {'certification': 'L',
#    'descriptors': [],
#    'iso_3166_1': 'BR',
#    'primary': False,
#    'release_date': '2021-02-11'},
#   {'certification': '7',
#    'descriptors': [],
#    'iso_3166_1': 'DK',
#    'primary': False,
#    'release_date': '2021-02-11'},
#   {'certification': 'G',
#    'descriptors': [],
#    'iso_3166_1': 'AU',
#    'primary': False,
#    'release_date': '2021-04-01'},
#   {'certification': '',
#    'descriptors': [],
#    'iso_3166_1': 'HK',
#    'primary': False,
#    'release_date': '2021-03-11'},
#   {'certification': 'U',
#    'descriptors': [],
#    'iso_3166_1': 'FR',
#    'primary': False,
#    'release_date': '2021-05-19'},
#   {'certification': 'Btl',
#    'descriptors': [],
#    'iso_3166_1': 'SE',
#    'primary': False,
#    'release_date': '2021-05-28'},
#   {'certification': '0',
#    'descriptors': [],
#    'iso_3166_1': 'DE',
#    'primary': False,
#    'release_date': '2021-06-17'},
#   {'certification': '',
#    'descriptors': [],
#    'iso_3166_1': 'CZ',
#    'primary': False,
#    'release_date': '2021-06-10'},
#   {'certification': 'U',
#    'descriptors': [],
#    'iso_3166_1': 'SK',
#    'primary': False,
#    'release_date': '2021-05-27'},
#   {'certification': 'V',
#    'descriptors': [],
#    'iso_3166_1': 'LT',
#    'primary': False,
#    'release_date': '2021-05-07'},
#   {'certification': '6',
#    'descriptors': [],
#    'iso_3166_1': 'HU',
#    'primary': False,
#    'release_date': '2021-05-20'},
#   {'certification': '',
#    'descriptors': [],
#    'iso_3166_1': 'PL',
#    'primary': False,
#    'release_date': '2021-06-11'},
#   {'certification': '7',
#    'descriptors': [],
#    'iso_3166_1': 'ES',
#    'primary': False,
#    'release_date': '2021-03-26'},
#   {'certification': 'PG',
#    'descriptors': [],
#    'iso_3166_1': 'SG',
#    'primary': False,
#    'release_date': '2021-02-11'},
#   {'certification': 'Κ',
#    'descriptors': [],
#    'iso_3166_1': 'GR',
#    'primary': False,
#    'release_date': '2021-06-10'},
#   {'certification': '普遍級',
#    'descriptors': [],
#    'iso_3166_1': 'TW',
#    'primary': False,
#    'release_date': '2021-02-10'},
#   {'certification': '',
#    'descriptors': [],
#    'iso_3166_1': 'KZ',
#    'primary': False,
#    'release_date': '2021-02-25'},
#   {'certification': 'PG',
#    'descriptors': [],
#    'iso_3166_1': 'US',
#    'primary': False,
#    'release_date': '2021-02-26'},
#   {'certification': 'PG',
#    'descriptors': [],
#    'iso_3166_1': 'GB',
#    'primary': False,
#    'release_date': '2021-03-25'},
#   {'certification': 'G',
#    'descriptors': [],
#    'iso_3166_1': 'AU',
#    'primary': False,
#    'release_date': '2021-06-01'},
#   {'certification': 'G',
#    'descriptors': [],
#    'iso_3166_1': 'NZ',
#    'primary': False,
#    'release_date': '2021-06-01'},
#   {'certification': 'U',
#    'descriptors': [],
#    'iso_3166_1': 'FR',
#    'primary': False,
#    'release_date': '2021-09-16'},
#   {'certification': 'U',
#    'descriptors': [],
#    'iso_3166_1': 'FR',
#    'primary': False,
#    'release_date': '2022-02-16'},
#   {'certification': 'PG',
#    'descriptors': [],
#    'iso_3166_1': 'GB',
#    'primary': False,
#    'release_date': '2021-05-24'},
#   {'certification': 'G',
#    'descriptors': [],
#    'iso_3166_1': 'AU',
#    'primary': False,
#    'release_date': '2021-06-21'},
#   {'certification': 'PG',
#    'descriptors': [],
#    'iso_3166_1': 'US',
#    'primary': False,
#    'release_date': '2021-05-18'},
#   {'certification': 'U',
#    'descriptors': [],
#    'iso_3166_1': 'FR',
#    'primary': False,
#    'release_date': '2021-09-22'},
#   {'certification': '',
#    'descriptors': [],
#    'iso_3166_1': 'GR',
#    'primary': False,
#    'release_date': '2021-09-23'},
#   {'certification': '',
#    'descriptors': [],
#    'iso_3166_1': 'CA',
#    'primary': False,
#    'release_date': '2021-07-31'}]}

# %%
response = movie.releases()
for c in movie.countries:
    if c['iso_3166_1'] == 'US':
        print(c['certification'])
# Out:
# PG
# PG
# PG

# %%
movie = tmdb.Movies('tt1361336')
info = movie.info()
releases = movie.releases()
    
for c in releases['countries']:
    if c ['iso_3166_1'] == 'US':
        info['certification'] = c['certification']

# %%
def get_movie_with_rating(movie_id):
    movie = tmdb.Movies('tt1361336')
    movie_info = movie.info()
    releases = movie.releases()
    
    for c in releases['countries']:
        if c['iso_3166_1'] == 'US':
            info['certification'] = c['certification']
            
    return movie_info

# %%
id = 'tt0848228'

# %%
get_movie_with_rating(id)
# Out:
# {'adult': False,
#  'backdrop_path': '/9ns9463dwOeo1CK1JU2wirL5Yi1.jpg',
#  'belongs_to_collection': None,
#  'budget': 50000000,
#  'genres': [{'id': 35, 'name': 'Comedy'},
#   {'id': 10751, 'name': 'Family'},
#   {'id': 16, 'name': 'Animation'}],
#  'homepage': 'https://www.tomandjerrymovie.com',
#  'id': 587807,
#  'imdb_id': 'tt1361336',
#  'original_language': 'en',
#  'original_title': 'Tom & Jerry',
#  'overview': 'Tom the cat and Jerry the mouse get kicked out of their home and relocate to a fancy New York hotel, where a scrappy employee named Kayla will lose her job if she can’t evict Jerry before a high-class wedding at the hotel. Her solution? Hiring Tom to get rid of the pesky mouse.',
#  'popularity': 46.466,
#  'poster_path': '/8XZI9QZ7Pm3fVkigWJPbrXCMzjq.jpg',
#  'production_companies': [{'id': 25120,
#    'logo_path': '/lMj6nMJBOzfLEd2fu8uF530AJcv.png',
#    'name': 'Warner Bros. Pictures Animation',
#    'origin_country': 'US'},
#   {'id': 8922,
#    'logo_path': '/yZWehAyjfKi4KvKeg1bkJ1bm5H8.png',
#    'name': 'Turner Entertainment',
#    'origin_country': 'US'},
#   {'id': 77061,
#    'logo_path': None,
#    'name': 'The Story Company',
#    'origin_country': 'US'},
#   {'id': 174,
#    'logo_path': '/IuAlhI9eVC9Z8UQWOIDdWRKSEJ.png',
#    'name': 'Warner Bros. Pictures',
#    'origin_country': 'US'}],
#  'production_countries': [{'iso_3166_1': 'US',
#    'name': 'United States of America'}],
#  'release_date': '2021-02-10',
#  'revenue': 136536687,
#  'runtime': 101,
#  'spoken_languages': [{'english_name': 'English',
#    'iso_639_1': 'en',
#    'name': 'English'}],
#  'status': 'Released',
#  'tagline': 'Best of enemies. Worst of friends.',
#  'title': 'Tom & Jerry',
#  'video': False,
#  'vote_average': 6.9,
#  'vote_count': 2243}

# %% [markdown]
# ## Efficient TMDB API Calls

# %%
from tqdm.notebook import tqdm_notebook

# %%
import os, time,json
import tmdbsimple as tmdb 
import pandas as pd
FOLDER = "Data/"
os.makedirs(FOLDER, exist_ok=True)
os.listdir(FOLDER)
# Out:
# ['filtered_basic_years_filtered.csv.gz',
#  'filtered_ratings.csv.gz',
#  'filtered_re_akas_cleaned.csv.gz',
#  'final_tmdb_data_2000.csv.gz',
#  'final_tmdb_data_2001.csv.gz',
#  'tmdb_api_results_2000.json',
#  'tmdb_api_results_2001.json']

# %%
def write_json(new_data, filename): 
    """Appends a list of records (new_data) to a json file (filename). 
    Adapted from: https://www.geeksforgeeks.org/append-to-json-file-using-python/"""  
    
    with open(filename,'r+') as file:
        # First we load existing data into a dict.
        file_data = json.load(file)
        ## Choose extend or append
        if (type(new_data) == list) & (type(file_data) == list):
            file_data.extend(new_data)
        else:
             file_data.append(new_data)
        # Sets file's current position at offset.
        file.seek(0)
        # convert back to json.
        json.dump(file_data, file)

# %%
df_basics = pd.read_csv(r'\Users\valma\OneDrive\Documents\GitHub\Project-3-Part-1\Data\filtered_basic_years_filtered.csv.gz')
df_basics.head()
# Out:
#       tconst titleType                                       primaryTitle  \
# 0  tt0035423     movie                                     Kate & Leopold
# 1  tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 2  tt0069049     movie                         The Other Side of the Wind
# 3  tt0088751     movie                                  The Naked Monster
# 4  tt0096056     movie                               Crime and Punishment
#
#                                originalTitle  isAdult  startYear  endYear  \
# 0                             Kate & Leopold        0     2001.0      NaN
# 1  El tango del viudo y su espejo deformante        0     2020.0      NaN
# 2                 The Other Side of the Wind        0     2018.0      NaN
# 3                          The Naked Monster        0     2005.0      NaN
# 4                       Crime and Punishment        0     2002.0      NaN
#
#    runtimeMinutes                  genres
# 0             118  Comedy,Fantasy,Romance
# 1              70                   Drama
# 2             122                   Drama
# 3             100    Comedy,Horror,Sci-Fi
# 4             126                   Drama

# %%
years_to_get = [2000,2001]

# %%
import pandas as pd 
basics = pd.read_csv(r'\Users\valma\OneDrive\Documents\GitHub\Project-3-Part-1\Data\filtered_basic_years_filtered.csv.gz')
basics.head()
# Out:
#       tconst titleType                                       primaryTitle  \
# 0  tt0035423     movie                                     Kate & Leopold
# 1  tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 2  tt0069049     movie                         The Other Side of the Wind
# 3  tt0088751     movie                                  The Naked Monster
# 4  tt0096056     movie                               Crime and Punishment
#
#                                originalTitle  isAdult  startYear  endYear  \
# 0                             Kate & Leopold        0     2001.0      NaN
# 1  El tango del viudo y su espejo deformante        0     2020.0      NaN
# 2                 The Other Side of the Wind        0     2018.0      NaN
# 3                          The Naked Monster        0     2005.0      NaN
# 4                       Crime and Punishment        0     2002.0      NaN
#
#    runtimeMinutes                  genres
# 0             118  Comedy,Fantasy,Romance
# 1              70                   Drama
# 2             122                   Drama
# 3             100    Comedy,Horror,Sci-Fi
# 4             126                   Drama

# %%
def write_json(new_data, filename): 
    """Adapted from: https://www.geeksforgeeks.org/append-to-json-file-using-python/"""    
    
    with open(filename,'r+') as file:
        # First we load existing data into a dict.
        file_data = json.load(file)
        ## Choose extend or append
        if (type(new_data) == list) & (type(file_data) == list):
            file_data.extend(new_data)
        else:
             file_data.append(new_data)
        # Sets file's current position at offset.
        file.seek(0)
        # convert back to json.
        json.dump(file_data, file)

# %%
for YEAR in tqdm_notebook(years_to_get, desc='YEARS', position=0):
    JSON_FILE = f'{FOLDER}tmdb_api_results_{YEAR}.json'
    file_exists = os.path.isfile(JSON_FILE)

    if file_exists == False:
        with open(JSON_FILE,'w') as f:
            json.dump([{'imdb_id':0}],f)

    df = basics.loc[basics['startYear']==YEAR].copy()

    movie_ids = df['tconst'].copy()
    movie_ids

    previous_df = pd.read_json(JSON_FILE)

    previous_df

    movie_ids_to_get = movie_ids[~movie_ids.isin(previous_df['imdb_id'])]

    for movie_id in tqdm_notebook(movie_ids_to_get,
                                  desc=f'Movies from {YEAR}',
                                  position=1,
                                  leave=True):
        try:
            # Retrieve then data for the movie id
            temp = get_movie_with_rating(movie_id)  
            # Append/extend results to existing file using a pre-made function
            write_json(temp,JSON_FILE)
            # Short 20 ms sleep to prevent overwhelming server
            time.sleep(0.02)
            
        except Exception as e:
            continue

    final_year_df = pd.read_json(JSON_FILE)
    final_year_df.to_csv(f"{FOLDER}final_tmdb_data_{YEAR}.csv.gz", compression="gzip", index=False)
# Out:
# YEARS:   0%|          | 0/2 [00:00<?, ?it/s]
# Movies from 2000:   0%|          | 0/520 [00:00<?, ?it/s]
# Movies from 2001:   0%|          | 0/2875 [00:00<?, ?it/s]

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# Load in your csv.gz's of results for each year extracted.
#   1. Concatenate the data into 1 dataframe for the remainder of the analysis.
#
#
# Once you have your data from the API, they would like you to perform some light EDA to show:
#    1. How many movies had at least some valid financial information (values > 0 for budget OR revenue)?
#    2. Please exclude any movies with 0's for budget AND revenue from the remaining visualizations.
#    3. How many movies are there in each of the certification categories (G/PG/PG-13/R)?
#    4. What is the average revenue per certification category?
#    5. What is the average budget per certification category?

# %%
df_final_2000 = pd.read_csv('Data/final_tmdb_data_2000.csv.gz')
df_final_2000.head()
# Out:
#      imdb_id  adult                     backdrop_path belongs_to_collection  \
# 0          0    NaN                               NaN                   NaN
# 1  tt0113026    0.0  /vMFs7nw6P0bIV1jDsQpxAieAVnH.jpg                   NaN
# 2  tt0113092    0.0                               NaN                   NaN
# 3  tt0116391    0.0                               NaN                   NaN
# 4  tt0116748    0.0  /wr0hTHwkYIRC82MwNbhOvqrw27N.jpg                   NaN
#
#        budget                                             genres homepage  \
# 0         NaN                                                NaN      NaN
# 1  10000000.0  [{'id': 35, 'name': 'Comedy'}, {'id': 10402, '...      NaN
# 2         0.0           [{'id': 878, 'name': 'Science Fiction'}]      NaN
# 3         0.0  [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...      NaN
# 4         0.0  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...      NaN
#
#          id original_language   original_title  ... revenue  runtime  \
# 0       NaN               NaN              NaN  ...     NaN      NaN
# 1   62127.0                en  The Fantasticks  ...     0.0     86.0
# 2  110977.0                en    For the Cause  ...     0.0    100.0
# 3  442869.0                hi             Gang  ...     0.0    152.0
# 4  579396.0                hi         Karobaar  ...     0.0    180.0
#
#                                     spoken_languages    status  \
# 0                                                NaN       NaN
# 1  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 2  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 3  [{'english_name': 'Hindi', 'iso_639_1': 'hi', ...  Released
# 4  [{'english_name': 'Hindi', 'iso_639_1': 'hi', ...  Released
#
#                                          tagline            title  video  \
# 0                                            NaN              NaN    NaN
# 1  Try to remember the first time magic happened  The Fantasticks    0.0
# 2   The ultimate showdown on a forbidden planet.    For the Cause    0.0
# 3                                            NaN             Gang    0.0
# 4                           The Business of Love         Karobaar    0.0
#
#    vote_average vote_count certification
# 0           NaN        NaN           NaN
# 1           5.5       22.0           NaN
# 2           5.1        8.0           NaN
# 3           4.0        1.0           NaN
# 4           7.0        3.0           NaN
#
# [5 rows x 26 columns]

# %%
df_final_2000.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6208 entries, 0 to 6207
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   imdb_id                6208 non-null   object
#  1   adult                  6207 non-null   float64
#  2   backdrop_path          3453 non-null   object
#  3   belongs_to_collection  244 non-null    object
#  4   budget                 6207 non-null   float64
#  5   genres                 6207 non-null   object
#  6   homepage               2139 non-null   object
#  7   id                     6207 non-null   float64
#  8   original_language      6207 non-null   object
#  9   original_title         6207 non-null   object
#  10  overview               5676 non-null   object
#  11  popularity             6207 non-null   float64
#  12  poster_path            5309 non-null   object
#  13  production_companies   6207 non-null   object
#  14  production_countries   6207 non-null   object
#  15  release_date           6136 non-null   object
#  16  revenue                6207 non-null   float64
#  17  runtime                6207 non-null   float64
#  18  spoken_languages       6207 non-null   object
#  19  status                 6207 non-null   object
#  20  tagline                2952 non-null   object
#  21  title                  6207 non-null   object
#  22  video                  6207 non-null   float64
#  23  vote_average           6207 non-null   float64
#  24  vote_count             6207 non-null   float64
#  25  certification          782 non-null    object
# dtypes: float64(9), object(17)
# memory usage: 1.2+ MB

# %%
df_final_2001 = pd.read_csv('Data/final_tmdb_data_2001.csv.gz')
df_final_2001
# Out:
#         imdb_id  adult                     backdrop_path  \
# 0             0    NaN                               NaN
# 1     tt1361336    0.0  /9ns9463dwOeo1CK1JU2wirL5Yi1.jpg
# 2     tt1361336    0.0  /9ns9463dwOeo1CK1JU2wirL5Yi1.jpg
# 3     tt1361336    0.0  /9ns9463dwOeo1CK1JU2wirL5Yi1.jpg
# 4     tt1361336    0.0  /9ns9463dwOeo1CK1JU2wirL5Yi1.jpg
# ...         ...    ...                               ...
# 6025  tt1361336    0.0  /9ns9463dwOeo1CK1JU2wirL5Yi1.jpg
# 6026  tt1361336    0.0  /9ns9463dwOeo1CK1JU2wirL5Yi1.jpg
# 6027  tt1361336    0.0  /9ns9463dwOeo1CK1JU2wirL5Yi1.jpg
# 6028  tt1361336    0.0  /9ns9463dwOeo1CK1JU2wirL5Yi1.jpg
# 6029  tt1361336    0.0  /9ns9463dwOeo1CK1JU2wirL5Yi1.jpg
#
#       belongs_to_collection      budget  \
# 0                       NaN         NaN
# 1                       NaN  50000000.0
# 2                       NaN  50000000.0
# 3                       NaN  50000000.0
# 4                       NaN  50000000.0
# ...                     ...         ...
# 6025                    NaN  50000000.0
# 6026                    NaN  50000000.0
# 6027                    NaN  50000000.0
# 6028                    NaN  50000000.0
# 6029                    NaN  50000000.0
#
#                                                  genres  \
# 0                                                   NaN
# 1     [{'id': 35, 'name': 'Comedy'}, {'id': 10751, '...
# 2     [{'id': 35, 'name': 'Comedy'}, {'id': 10751, '...
# 3     [{'id': 35, 'name': 'Comedy'}, {'id': 10751, '...
# 4     [{'id': 35, 'name': 'Comedy'}, {'id': 10751, '...
# ...                                                 ...
# 6025  [{'id': 35, 'name': 'Comedy'}, {'id': 10751, '...
# 6026  [{'id': 35, 'name': 'Comedy'}, {'id': 10751, '...
# 6027  [{'id': 35, 'name': 'Comedy'}, {'id': 10751, '...
# 6028  [{'id': 35, 'name': 'Comedy'}, {'id': 10751, '...
# 6029  [{'id': 35, 'name': 'Comedy'}, {'id': 10751, '...
#
#                               homepage        id original_language  \
# 0                                  NaN       NaN               NaN
# 1     https://www.tomandjerrymovie.com  587807.0                en
# 2     https://www.tomandjerrymovie.com  587807.0                en
# 3     https://www.tomandjerrymovie.com  587807.0                en
# 4     https://www.tomandjerrymovie.com  587807.0                en
# ...                                ...       ...               ...
# 6025  https://www.tomandjerrymovie.com  587807.0                en
# 6026  https://www.tomandjerrymovie.com  587807.0                en
# 6027  https://www.tomandjerrymovie.com  587807.0                en
# 6028  https://www.tomandjerrymovie.com  587807.0                en
# 6029  https://www.tomandjerrymovie.com  587807.0                en
#
#      original_title  ... release_date      revenue runtime  \
# 0               NaN  ...          NaN          NaN     NaN
# 1       Tom & Jerry  ...   2021-02-10  136536687.0   101.0
# 2       Tom & Jerry  ...   2021-02-10  136536687.0   101.0
# 3       Tom & Jerry  ...   2021-02-10  136536687.0   101.0
# 4       Tom & Jerry  ...   2021-02-10  136536687.0   101.0
# ...             ...  ...          ...          ...     ...
# 6025    Tom & Jerry  ...   2021-02-10  136536687.0   101.0
# 6026    Tom & Jerry  ...   2021-02-10  136536687.0   101.0
# 6027    Tom & Jerry  ...   2021-02-10  136536687.0   101.0
# 6028    Tom & Jerry  ...   2021-02-10  136536687.0   101.0
# 6029    Tom & Jerry  ...   2021-02-10  136536687.0   101.0
#
#                                        spoken_languages    status  \
# 0                                                   NaN       NaN
# 1     [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 2     [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 3     [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 4     [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# ...                                                 ...       ...
# 6025  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 6026  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 6027  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 6028  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 6029  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
#
#                                  tagline        title  video vote_average  \
# 0                                    NaN          NaN    NaN          NaN
# 1     Best of enemies. Worst of friends.  Tom & Jerry    0.0          6.9
# 2     Best of enemies. Worst of friends.  Tom & Jerry    0.0          6.9
# 3     Best of enemies. Worst of friends.  Tom & Jerry    0.0          6.9
# 4     Best of enemies. Worst of friends.  Tom & Jerry    0.0          6.9
# ...                                  ...          ...    ...          ...
# 6025  Best of enemies. Worst of friends.  Tom & Jerry    0.0          6.9
# 6026  Best of enemies. Worst of friends.  Tom & Jerry    0.0          6.9
# 6027  Best of enemies. Worst of friends.  Tom & Jerry    0.0          6.9
# 6028  Best of enemies. Worst of friends.  Tom & Jerry    0.0          6.9
# 6029  Best of enemies. Worst of friends.  Tom & Jerry    0.0          6.9
#
#      vote_count
# 0           NaN
# 1        2243.0
# 2        2243.0
# 3        2243.0
# 4        2243.0
# ...         ...
# 6025     2243.0
# 6026     2243.0
# 6027     2243.0
# 6028     2243.0
# 6029     2243.0
#
# [6030 rows x 25 columns]

# %%
df_final_2001.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6030 entries, 0 to 6029
# Data columns (total 25 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   imdb_id                6030 non-null   object
#  1   adult                  6029 non-null   float64
#  2   backdrop_path          6029 non-null   object
#  3   belongs_to_collection  0 non-null      float64
#  4   budget                 6029 non-null   float64
#  5   genres                 6029 non-null   object
#  6   homepage               6029 non-null   object
#  7   id                     6029 non-null   float64
#  8   original_language      6029 non-null   object
#  9   original_title         6029 non-null   object
#  10  overview               6029 non-null   object
#  11  popularity             6029 non-null   float64
#  12  poster_path            6029 non-null   object
#  13  production_companies   6029 non-null   object
#  14  production_countries   6029 non-null   object
#  15  release_date           6029 non-null   object
#  16  revenue                6029 non-null   float64
#  17  runtime                6029 non-null   float64
#  18  spoken_languages       6029 non-null   object
#  19  status                 6029 non-null   object
#  20  tagline                6029 non-null   object
#  21  title                  6029 non-null   object
#  22  video                  6029 non-null   float64
#  23  vote_average           6029 non-null   float64
#  24  vote_count             6029 non-null   float64
# dtypes: float64(10), object(15)
# memory usage: 1.2+ MB

# %%
df_final_merged = pd.concat([df_final_2000,df_final_2001],ignore_index = True, sort = False)
df_final_merged
# Out:
#          imdb_id  adult                     backdrop_path  \
# 0              0    NaN                               NaN
# 1      tt0113026    0.0  /vMFs7nw6P0bIV1jDsQpxAieAVnH.jpg
# 2      tt0113092    0.0                               NaN
# 3      tt0116391    0.0                               NaN
# 4      tt0116748    0.0  /wr0hTHwkYIRC82MwNbhOvqrw27N.jpg
# ...          ...    ...                               ...
# 12233  tt1361336    0.0  /9ns9463dwOeo1CK1JU2wirL5Yi1.jpg
# 12234  tt1361336    0.0  /9ns9463dwOeo1CK1JU2wirL5Yi1.jpg
# 12235  tt1361336    0.0  /9ns9463dwOeo1CK1JU2wirL5Yi1.jpg
# 12236  tt1361336    0.0  /9ns9463dwOeo1CK1JU2wirL5Yi1.jpg
# 12237  tt1361336    0.0  /9ns9463dwOeo1CK1JU2wirL5Yi1.jpg
#
#       belongs_to_collection      budget  \
# 0                       NaN         NaN
# 1                       NaN  10000000.0
# 2                       NaN         0.0
# 3                       NaN         0.0
# 4                       NaN         0.0
# ...                     ...         ...
# 12233                   NaN  50000000.0
# 12234                   NaN  50000000.0
# 12235                   NaN  50000000.0
# 12236                   NaN  50000000.0
# 12237                   NaN  50000000.0
#
#                                                   genres  \
# 0                                                    NaN
# 1      [{'id': 35, 'name': 'Comedy'}, {'id': 10402, '...
# 2               [{'id': 878, 'name': 'Science Fiction'}]
# 3      [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...
# 4      [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# ...                                                  ...
# 12233  [{'id': 35, 'name': 'Comedy'}, {'id': 10751, '...
# 12234  [{'id': 35, 'name': 'Comedy'}, {'id': 10751, '...
# 12235  [{'id': 35, 'name': 'Comedy'}, {'id': 10751, '...
# 12236  [{'id': 35, 'name': 'Comedy'}, {'id': 10751, '...
# 12237  [{'id': 35, 'name': 'Comedy'}, {'id': 10751, '...
#
#                                homepage        id original_language  \
# 0                                   NaN       NaN               NaN
# 1                                   NaN   62127.0                en
# 2                                   NaN  110977.0                en
# 3                                   NaN  442869.0                hi
# 4                                   NaN  579396.0                hi
# ...                                 ...       ...               ...
# 12233  https://www.tomandjerrymovie.com  587807.0                en
# 12234  https://www.tomandjerrymovie.com  587807.0                en
# 12235  https://www.tomandjerrymovie.com  587807.0                en
# 12236  https://www.tomandjerrymovie.com  587807.0                en
# 12237  https://www.tomandjerrymovie.com  587807.0                en
#
#         original_title  ...      revenue  runtime  \
# 0                  NaN  ...          NaN      NaN
# 1      The Fantasticks  ...          0.0     86.0
# 2        For the Cause  ...          0.0    100.0
# 3                 Gang  ...          0.0    152.0
# 4             Karobaar  ...          0.0    180.0
# ...                ...  ...          ...      ...
# 12233      Tom & Jerry  ...  136536687.0    101.0
# 12234      Tom & Jerry  ...  136536687.0    101.0
# 12235      Tom & Jerry  ...  136536687.0    101.0
# 12236      Tom & Jerry  ...  136536687.0    101.0
# 12237      Tom & Jerry  ...  136536687.0    101.0
#
#                                         spoken_languages    status  \
# 0                                                    NaN       NaN
# 1      [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 2      [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 3      [{'english_name': 'Hindi', 'iso_639_1': 'hi', ...  Released
# 4      [{'english_name': 'Hindi', 'iso_639_1': 'hi', ...  Released
# ...                                                  ...       ...
# 12233  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 12234  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 12235  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 12236  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 12237  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
#
#                                              tagline            title  video  \
# 0                                                NaN              NaN    NaN
# 1      Try to remember the first time magic happened  The Fantasticks    0.0
# 2       The ultimate showdown on a forbidden planet.    For the Cause    0.0
# 3                                                NaN             Gang    0.0
# 4                               The Business of Love         Karobaar    0.0
# ...                                              ...              ...    ...
# 12233             Best of enemies. Worst of friends.      Tom & Jerry    0.0
# 12234             Best of enemies. Worst of friends.      Tom & Jerry    0.0
# 12235             Best of enemies. Worst of friends.      Tom & Jerry    0.0
# 12236             Best of enemies. Worst of friends.      Tom & Jerry    0.0
# 12237             Best of enemies. Worst of friends.      Tom & Jerry    0.0
#
#        vote_average vote_count certification
# 0               NaN        NaN           NaN
# 1               5.5       22.0           NaN
# 2               5.1        8.0           NaN
# 3               4.0        1.0           NaN
# 4               7.0        3.0           NaN
# ...             ...        ...           ...
# 12233           6.9     2243.0           NaN
# 12234           6.9     2243.0           NaN
# 12235           6.9     2243.0           NaN
# 12236           6.9     2243.0           NaN
# 12237           6.9     2243.0           NaN
#
# [12238 rows x 26 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_final_merged.

# %%
sns.barplot(df_final_merged, x='revenue', y = 'budget')
# Out:
# <AxesSubplot: xlabel='revenue', ylabel='budget'>
